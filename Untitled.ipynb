# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'font.size': 14})

# %%
filename = 'data/' + "2018-04-2921.39.19 landing.csv"
#filename = 'data/' + "2018-04-3010.36.46 test.csv"
#filename = 'data/' + "2018-04-2920.53.10 turb.csv"
filename = 'data/' + "2018-04-3010.58.40 lab1.csv"
filename = 'data/' + "DOC-20180506-WA0011.csv"

filename = 'data/' + "2018-05-08_decoVienne.csv"

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import dyna as dy

# %%
data = dy.readcsv( filename, timeAbsolute=True )

# %%
plt.plot(data['time'])

# %%
M = dy.Measure( data )

M.setmask( 0, 200 )

#M.smooth( 40 )

# %%
M.plotGforces()

# %%
mask = (data['time'] > 30)&(data['time'] < data['time'][-1]-80)

# %%
plt.figure(figsize=(12, 3))
plt.plot( data['time'][mask], data['Gain'][mask], 'r-' )
plt.xlabel('time [s]');
plt.xlim( min(data['time'][mask]), max(data['time'][mask]) )
plt.ylabel('Gain');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-1fef394a3cd5> in <module>()
#       1 plt.figure(figsize=(12, 3))
# ----> 2 plt.plot( data['time'][mask], data['Gain'][mask], 'r-' )
#       3 plt.xlabel('time [s]');
#       4 plt.xlim( min(data['time'][mask]), max(data['time'][mask]) )
#       5 plt.ylabel('Gain');
#
# KeyError: 'Gain'

# %%
plt.figure(figsize=(12, 6))
plt.subplot( 4, 1, 1 )
plt.plot( data['time'][mask], data['gFx'][mask], '-' )
plt.ylabel('gFx');
plt.xlim( min(data['time'][mask]), max(data['time'][mask]) )
plt.tick_params(labelbottom='off')

plt.subplot( 4, 1, 2 )
plt.plot( data['time'][mask], data['gFy'][mask], '-' )
plt.ylabel('gFy');
plt.xlim( min(data['time'][mask]), max(data['time'][mask]) )
plt.tick_params(labelbottom='off')

plt.subplot( 4, 1, 3 )
plt.plot( data['time'][mask], data['gFz'][mask], '-' )
plt.xlabel('time (s)');
plt.xlim( min(data['time'][mask]), max(data['time'][mask]) )
plt.ylabel('gFz');
plt.tick_params(labelbottom='off')


gFx = data['gFx'][mask]
gFy = data['gFy'][mask]
gFz = data['gFz'][mask]
gFnorm = np.sqrt( gFx**2 + gFy**2 + gFz**2  )

plt.subplot( 4, 1, 4 )
plt.axhline( y=1, color='k', linewidth=1 )
plt.plot( data['time'][mask], gFnorm, 'r-' )
plt.xlabel('time (s)');
plt.xlim( min(data['time'][mask]), max(data['time'][mask]) )
plt.ylabel('norm');

# %%
plt.figure(figsize=(12, 5))
plt.subplot( 3, 1, 1 )
plt.plot( data['time'][mask], data['Azimuth'][mask], 'm-' )
plt.ylabel('Azimuth');
plt.xlim( min(data['time'][mask]), max(data['time'][mask]) )
plt.tick_params(labelbottom='off')

plt.subplot( 3, 1, 2 )
plt.plot( data['time'][mask], data['Pitch'][mask], 'r-' )
plt.ylabel('Pitch');
plt.xlim( min(data['time'][mask]), max(data['time'][mask]) )
plt.tick_params(labelbottom='off')

plt.subplot( 3, 1, 3 )
plt.plot( data['time'][mask], data['Roll'][mask], '-' )
plt.xlabel('time (s)');
plt.xlim( min(data['time'][mask]), max(data['time'][mask]) )
plt.ylabel('Roll');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-ea74d8c17af5> in <module>()
#       1 plt.figure(figsize=(12, 5))
#       2 plt.subplot( 3, 1, 1 )
# ----> 3 plt.plot( data['time'][mask], data['Azimuth'][mask], 'm-' )
#       4 plt.ylabel('Azimuth');
#       5 plt.xlim( min(data['time'][mask]), max(data['time'][mask]) )
#
# KeyError: 'Azimuth'
